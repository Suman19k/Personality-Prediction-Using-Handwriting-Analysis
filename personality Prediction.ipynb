# %%
import os
import matplotlib.pyplot as plt 
import cv2 
import tensorflow as tf
from tensorflow.keras.preprocessing import image

# %%
#reading and printing the image using cv2 
#the image is printed in the format of an array 
img1=cv2.imread(r'C:\Users\suman\OneDrive\Desktop\Personality Prediction Code\Training Dataset\training\Openness\opness (167).png')
print(img1)
# Out:
# [[[243 243 243]
#   [247 247 247]
#   [244 244 244]
#   ...
#   [245 245 245]
#   [243 243 243]
#   [245 245 245]]
#
#  [[244 244 244]
#   [244 244 244]
#   [246 246 246]
#   ...
#   [248 248 248]
#   [247 247 247]
#   [247 247 247]]
#
#  [[246 246 246]
#   [243 243 243]
#   [244 244 244]
#   ...
#   [248 248 248]
#   [249 249 249]
#   [246 246 246]]
#
#  ...
#
#  [[245 245 245]
#   [247 247 247]
#   [246 246 246]
#   ...
#   [247 247 247]
#   [245 245 245]
#   [247 247 247]]
#
#  [[247 247 247]
#   [249 249 249]
#   [245 245 245]
#   ...
#   [246 246 246]
#   [247 247 247]
#   [248 248 248]]
#
#  [[247 247 247]
#   [246 246 246]
#   [246 246 246]
#   ...
#   [245 245 245]
#   [246 246 246]
#   [246 246 246]]]

# %%
#previewing the image using open cv 
plt.imshow(img1)

# %%
#evaluating the size of the image 
print("the shape of the image ")
print(img1.shape)
#so we can see that the image has height=64 px , width=64 px , channel= 3
#so the image is an rgb image
# Out:
# the shape of the image
# (238, 537, 3)

# %%
#converting the rgb image to an grayscale image 
img_gray=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray)

# %%
#checking the shape of the gray image 
print("the shape of the converted image")
img_gray.shape
#here we can see that there is only 64,64 which describes the height and width and there is only one channel
# Out:
# the shape of the converted image
# (238, 537)

# %%
#Checking the array format of the single channel image 
img_gray
# Out:
# array([[243, 247, 244, ..., 245, 243, 245],
#        [244, 244, 246, ..., 248, 247, 247],
#        [246, 243, 244, ..., 248, 249, 246],
#        ...,
#        [245, 247, 246, ..., 247, 245, 247],
#        [247, 249, 245, ..., 246, 247, 248],
#        [247, 246, 246, ..., 245, 246, 246]], dtype=uint8)

# %%
#playing with the colors of the image 
import numpy as np
imgblue=img1[:,:,0]
imggreen=img1[:,:,1]
imgred=img1[:,:,2]
new_image=np.hstack((imgblue,imggreen,imgred))
plt.imshow(new_image)
#so here we can see that since the image does not contain any colors whatever the changes made in the 
#color channel does not reflect on the image

# %%
img = cv2.imread(r'C:\Users\suman\OneDrive\Desktop\Personality Prediction Code\Training Dataset\training\Anxious\A (477).png', 0)
plt.imshow(img, cmap='gray'), plt.grid(False)
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))

# %%
hist = cv2.calcHist([img],[0],None,[50],[0,256])

# different methods for displaying a histogram
plt.bar(range(50), hist.ravel())
plt.title('Histogram of the Handwritten Image image')
plt.xlabel('Gray values')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import numpy as np
hist,bins = np.histogram(img.ravel(),256,[0,256])
plt.plot(hist)

# %%
from skimage import io
import os
import glob
import numpy as np
import random

DATASET_PATH = r'C:\Users\suman\OneDrive\Desktop\Personality Prediction Code\Training Dataset\training'
autism_cls = ['Anxious', 'Cooperative','Openness','Responsible','System image']


autism_path = os.path.join(DATASET_PATH, autism_cls[1], '*')
autism_path = glob.glob(autism_path)
# access some element (a file) from the list
image = io.imread(autism_path[5])

# %%
# plotting the original image and the RGB channels
f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=True)
f.set_figwidth(15)
ax1.imshow(image)

# RGB channels
# CHANNELID : 0 for Red, 1 for Green, 2 for Blue. 
ax2.imshow(image[:, : , 0]) #Red
ax3.imshow(image[:, : , 1]) #Green
ax4.imshow(image[:, : , 2]) #Blue
f.suptitle('Different Channels of Image')
# Out:
# Text(0.5, 0.98, 'Different Channels of Image')

# %%
import keras
import tensorflow
from skimage import io
import os
import glob
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# function to plot n images using subplots
def plot_image(images, captions=None, cmap=None ):
    f, axes = plt.subplots(1, len(images), sharey=True)
    f.set_figwidth(15)
    for ax,image in zip(axes, images):
        ax.imshow(image, cmap)

# %%
# globbing example
# help(glob)
autism_path = os.path.join(DATASET_PATH, autism_cls[2], '*')
print(autism_path)

# glob through the directory (returns a list of all file paths)
autism_path = glob.glob(autism_path)
print(autism_path[3]) # access an individual file
# Out:
# C:\Users\suman\OneDrive\Desktop\Personality Prediction Code\Training Dataset\training\Openness\*
# C:\Users\suman\OneDrive\Desktop\Personality Prediction Code\Training Dataset\training\Openness\opness (101).png

# %%
# run this block multiple times to look at some randomly chosen images of roses
rand_index = random.randint(0, len(autism_path))
image = io.imread(autism_path[rand_index])
plt.imshow(image)

# %%
# plot a sample image
autism_path = os.path.join(DATASET_PATH, autism_cls[3], '*')
autism_path = glob.glob(autism_path)

# access some element (a file) from the list
#image = io.imread(autism_path[54])
image = io.imread(autism_path[101])
plt.imshow(image)

# %%
# plotting the original image and the RGB channels
f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=True)
f.set_figwidth(15)
ax1.imshow(image)

# RGB channels
# CHANNELID : 0 for Red, 1 for Green, 2 for Blue. 
ax2.imshow(image[:, : , 0]) #Red
ax3.imshow(image[:, : , 1]) #Green
ax4.imshow(image[:, : , 2]) #Blue
f.suptitle('Different Channels of Image')
# Out:
# Text(0.5, 0.98, 'Different Channels of Image')

# %%
# bin_image will be a (240, 320) True/False array
#The range of pixel varies between 0 to 255
#The pixel having black is more close to 0 and pixel which is white is more close to 255
# 125 is Arbitrary heuristic measure halfway between 1 and 255 (the range of image pixel) 
bin_image = image[:, :, 0] > 150
plot_image([image, bin_image], cmap='gray')

# %%
from skimage.morphology import binary_closing, binary_dilation, binary_erosion, binary_opening
from skimage.morphology import disk

# use a disk of radius 3
selem = disk(3)

# oprning and closing
open_img = binary_opening(bin_image, selem)
close_img = binary_closing(bin_image, selem)

# erosion and dilation
eroded_img = binary_erosion(bin_image, selem)
dilated_img = binary_dilation(bin_image, selem)

plot_image([bin_image, open_img, eroded_img], cmap='gray')

# %% [markdown]
# # CNN

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers

# %%
images_dir = r"C:\Users\suman\OneDrive\Desktop\Personality Prediction Code\Training Dataset\training"

# %%
batch_size = 32
img_height = 300
img_width = 300

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  images_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2924 files belonging to 6 classes.
# Using 2632 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  images_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2924 files belonging to 6 classes.
# Using 877 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Anxious', 'Cooperative', 'Enthusiastic', 'Openness', 'Responsible', 'System image']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 300, 300, 3)
# (32,)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = 6

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_3 (Rescaling)     (None, 300, 300, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 300, 300, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 150, 150, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 150, 150, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 75, 75, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 87616)             0
#
#  dense_5 (Dense)             (None, 128)               11214976
#
#  dense_6 (Dense)             (None, 6)                 774
#
# ...
# Total params: 11,239,334
# Trainable params: 11,239,334
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 83/83 [==============================] - 96s 1s/step - loss: 1.0827 - accuracy: 0.6079 - val_loss: 0.5134 - val_accuracy: 0.8677
# Epoch 2/10
# 83/83 [==============================] - 108s 1s/step - loss: 0.2574 - accuracy: 0.9115 - val_loss: 0.2171 - val_accuracy: 0.9236
# Epoch 3/10
# 83/83 [==============================] - 101s 1s/step - loss: 0.1325 - accuracy: 0.9567 - val_loss: 0.0875 - val_accuracy: 0.9829
# Epoch 4/10
# 83/83 [==============================] - 97s 1s/step - loss: 0.0901 - accuracy: 0.9688 - val_loss: 0.1301 - val_accuracy: 0.9624
# Epoch 5/10
# 83/83 [==============================] - 92s 1s/step - loss: 0.0541 - accuracy: 0.9833 - val_loss: 0.0591 - val_accuracy: 0.9818
# Epoch 6/10
# 83/83 [==============================] - 167s 2s/step - loss: 0.0283 - accuracy: 0.9920 - val_loss: 0.0526 - val_accuracy: 0.9886
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
test_generator = ImageDataGenerator()
test_data_generator = test_generator.flow_from_directory(
    images_dir, # Put your path here
     target_size=(img_width, img_height),
    batch_size=32,
    shuffle=False)
test_steps_per_epoch = np.math.ceil(test_data_generator.samples / test_data_generator.batch_size)

predictions = model.predict_generator(test_data_generator, steps=test_steps_per_epoch)
# Get most likely class
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# Found 2924 images belonging to 6 classes.
# C:\Users\suman\AppData\Local\Temp\ipykernel_19980\2664318057.py:10: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(test_data_generator, steps=test_steps_per_epoch)

# %%
true_classes = test_data_generator.classes
class_labels = list(test_data_generator.class_indices.keys())

# %%
true_classes = test_data_generator.classes
class_labels = list(test_data_generator.class_indices.keys())

# %%
import sklearn.metrics as metrics
report = metrics.classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Anxious       0.90      1.00      0.95       545
#  Cooperative       1.00      0.93      0.96       558
# Enthusiastic       0.98      1.00      0.99       563
#     Openness       1.00      0.87      0.93       501
#  Responsible       0.94      1.00      0.97       527
# System image       1.00      0.97      0.98       230
#
#     accuracy                           0.96      2924
#    macro avg       0.97      0.96      0.96      2924
# weighted avg       0.97      0.96      0.96      2924

# %%
model.save("personalityhandwriting.h5")

# %% [markdown]
# # VGG16

# %%
from tensorflow import keras
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPool2D,Flatten,Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
import numpy as np

# %%
trdata=ImageDataGenerator()
traindata=trdata.flow_from_directory(directory=r'C:\Users\suman\OneDrive\Desktop\Personality Prediction Code\Training Dataset\training',target_size=(224,224))
tsdata=ImageDataGenerator()
testdata=tsdata.flow_from_directory(directory=r'C:\Users\suman\OneDrive\Desktop\Personality Prediction Code\Training Dataset\training',target_size=(224,224))
# Out:
# Found 2924 images belonging to 6 classes.
# Found 2924 images belonging to 6 classes.

# %%
#importing VGG16 algorithm 
VGG=keras.applications.VGG16(input_shape=(224,224,3),include_top=False,weights='imagenet')
VGG.trainable=False

# %%
model=keras.Sequential([
    VGG,
    keras.layers.Flatten(),
    keras.layers.Dense(units=256,activation='relu'),
    keras.layers.Dense(units=256,activation='relu'),
    keras.layers.Dense(units=6,activation='softmax')
    
])

# %%
model.compile(optimizer='adam',loss=tf.losses.CosineSimilarity(),metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_5 (Flatten)         (None, 25088)             0
#
#  dense_13 (Dense)            (None, 256)               6422784
#
#  dense_14 (Dense)            (None, 256)               65792
#
#  dense_15 (Dense)            (None, 6)                 1542
#
# ...
# Total params: 21,204,806
# Trainable params: 6,490,118
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
hist=model.fit_generator(steps_per_epoch=2,generator=traindata,validation_data=testdata,validation_steps=2,epochs=10)
# Out:
# Epoch 1/10
# C:\Users\suman\AppData\Local\Temp\ipykernel_19980\588456409.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist=model.fit_generator(steps_per_epoch=2,generator=traindata,validation_data=testdata,validation_steps=2,epochs=10)
# 2/2 [==============================] - 15s 10s/step - loss: -0.2814 - accuracy: 0.2500 - val_loss: -0.2969 - val_accuracy: 0.2969
# Epoch 2/10
# 2/2 [==============================] - 17s 14s/step - loss: -0.3358 - accuracy: 0.3281 - val_loss: -0.4216 - val_accuracy: 0.4219
# Epoch 3/10
# 2/2 [==============================] - 18s 14s/step - loss: -0.4456 - accuracy: 0.4375 - val_loss: -0.5156 - val_accuracy: 0.5156
# Epoch 4/10
# 2/2 [==============================] - 23s 18s/step - loss: -0.6406 - accuracy: 0.6406 - val_loss: -0.4770 - val_accuracy: 0.4688
# Epoch 5/10
# ...

# %%
import numpy as np
test_generator = ImageDataGenerator()
test_data_generator = test_generator.flow_from_directory(
    images_dir, # Put your path here
     target_size=(224, 224),
    batch_size=32,
    shuffle=False)
test_steps_per_epoch = np.math.ceil(test_data_generator.samples / test_data_generator.batch_size)

predictions = model.predict_generator(test_data_generator, steps=test_steps_per_epoch)
# Get most likely class
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# Found 2924 images belonging to 6 classes.
# C:\Users\suman\AppData\Local\Temp\ipykernel_19980\1110166086.py:10: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(test_data_generator, steps=test_steps_per_epoch)

# %%
true_classes = test_data_generator.classes
class_labels = list(test_data_generator.class_indices.keys())

# %%
import sklearn.metrics as metrics
report = metrics.classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Anxious       1.00      0.63      0.78       545
#  Cooperative       0.00      0.00      0.00       558
# Enthusiastic       0.00      0.00      0.00       563
#     Openness       0.60      0.98      0.74       501
#  Responsible       0.32      0.99      0.48       527
# System image       1.00      0.54      0.70       230
#
#     accuracy                           0.51      2924
#    macro avg       0.49      0.52      0.45      2924
# weighted avg       0.42      0.51      0.41      2924
# c:\Users\suman\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
import matplotlib.pyplot as plt
from keras.applications.densenet import DenseNet121, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input
from keras.models import Model
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam
#from generator import DataGenerator
import keras
from keras.callbacks import ModelCheckpoint
import os

# %%
labels = os.listdir(r'C:\Users\suman\OneDrive\Desktop\Personality Prediction Code\Training Dataset\training')
train_datagen = ImageDataGenerator(samplewise_center=True, 
                              samplewise_std_normalization=True, 
                              horizontal_flip = True, 
                              vertical_flip = False, 
                              height_shift_range= 0.05, 
                              width_shift_range=0.1, 
                              rotation_range=15, 
                              zoom_range=0.15,
                                   validation_split=0.2)

# %%
IMG_SIZE = 224
batch_size = 32
train_data_dir = r'C:\Users\suman\OneDrive\Desktop\Personality Prediction Code\Training Dataset\training'
validation_data_dir = r'C:\Users\suman\OneDrive\Desktop\Personality Prediction Code\Training Dataset\training'
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(IMG_SIZE , IMG_SIZE),
    batch_size=16,
    subset='training',
    class_mode='categorical')
valid_X, valid_Y = next(train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(IMG_SIZE , IMG_SIZE),
    batch_size=32,
    subset='validation',
    class_mode='categorical'))
# Out:
# Found 2341 images belonging to 6 classes.
# Found 583 images belonging to 6 classes.

# %%
t_x, t_y = next(train_generator)
fig, m_axs = plt.subplots(4, 4, figsize = (16, 16))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone')
    c_ax.set_title(', '.join([n_class for n_class, n_score in zip(labels, c_y) 
                             if n_score>0.5]))
    c_ax.axis('off')

# %%
# defining densenet model
# defining densenet model
def densenet_model():
    img_in = Input(t_x.shape[1:])              #input of model 
    model = DenseNet121(include_top= False , # remove  the 3 fully-connected layers at the top of the network
                weights='imagenet',      # pre train weight 
                input_tensor= img_in, 
                input_shape= t_x.shape[1:],
                pooling ='avg') 
    x = model.output  
    predictions = Dense(6, activation="softmax", name="predictions")(x)    # fuly connected layer for predict class 
    model = Model(inputs=img_in, outputs=predictions)
    return model

# %%
# compiling model
model = densenet_model()
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy',
                           metrics = ['accuracy'])

# %%
# creating checkpoint
filepath="personality.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
history = model.fit_generator(train_generator, 
                                  steps_per_epoch=15,
                                  validation_data = (valid_X,valid_Y), 
                                  epochs = 5,
                                  callbacks=callbacks_list)
# Out:
# C:\Users\suman\AppData\Local\Temp\ipykernel_19980\4094591282.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator,
# Epoch 1/5
# ...
# 15/15 [==============================] - 144s 8s/step - loss: 0.5679 - accuracy: 0.8292 - val_loss: 8.3599 - val_accuracy: 0.3750
# Epoch 2/5
# ...
# 15/15 [==============================] - 114s 8s/step - loss: 0.4730 - accuracy: 0.8583 - val_loss: 285.9473 - val_accuracy: 0.1875
# Epoch 3/5
# ...
# 15/15 [==============================] - 115s 8s/step - loss: 0.5029 - accuracy: 0.9125 - val_loss: 1093.6803 - val_accuracy: 0.1250
# Epoch 4/5
# ...
# 15/15 [==============================] - 119s 8s/step - loss: 0.2620 - accuracy: 0.9000 - val_loss: 249.3131 - val_accuracy: 0.2812
# Epoch 5/5
# ...
# 15/15 [==============================] - 141s 9s/step - loss: 0.2539 - accuracy: 0.8958 - val_loss: 15.3935 - val_accuracy: 0.3438

# %%
import numpy as np
test_generator = ImageDataGenerator()
test_data_generator = test_generator.flow_from_directory(
    images_dir, # Put your path here
     target_size=(224, 224),
    batch_size=32,
    shuffle=False)
test_steps_per_epoch = np.math.ceil(test_data_generator.samples / test_data_generator.batch_size)

predictions = model.predict_generator(test_data_generator, steps=test_steps_per_epoch)
# Get most likely class
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# Found 2924 images belonging to 6 classes.
# C:\Users\suman\AppData\Local\Temp\ipykernel_19980\1110166086.py:10: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(test_data_generator, steps=test_steps_per_epoch)

# %%
true_classes = test_data_generator.classes
class_labels = list(test_data_generator.class_indices.keys())

# %%
import sklearn.metrics as metrics
report = metrics.classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Anxious       0.00      0.00      0.00       545
#  Cooperative       0.19      1.00      0.32       558
# Enthusiastic       0.00      0.00      0.00       563
#     Openness       0.00      0.00      0.00       501
#  Responsible       0.00      0.00      0.00       527
# System image       0.00      0.00      0.00       230
#
#     accuracy                           0.19      2924
#    macro avg       0.03      0.17      0.05      2924
# weighted avg       0.04      0.19      0.06      2924
# c:\Users\suman\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # DenseNet

# %%
# Defining ResNet model
from tensorflow.keras.applications.resnet50 import ResNet50
def resnet_model():
    img_in = Input(t_x.shape[1:])              #input of model 
    model = ResNet50(include_top= False , # remove  the 3 fully-connected layers at the top of the network
                weights='imagenet',      # pre train weight 
                input_tensor= img_in, 
                input_shape= t_x.shape[1:],
                pooling ='avg') 
    x = model.output  
    predictions = Dense(6, activation="softmax", name="predictions")(x)    # fuly connected layer for predict class 
    model = Model(inputs=img_in, outputs=predictions)
    return model

# %%
# compiling model
model = resnet_model()
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy',
                           metrics = ['accuracy'])

# %%
history = model.fit_generator(train_generator, 
                                  steps_per_epoch=10,
                                  validation_data = (valid_X,valid_Y), 
                                  epochs = 5,
                                  callbacks=callbacks_list)
# Out:
# C:\Users\suman\AppData\Local\Temp\ipykernel_19980\165504017.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator,
# Epoch 1/5
# ...
# 10/10 [==============================] - 74s 6s/step - loss: 1.4716 - accuracy: 0.6687 - val_loss: 785.8237 - val_accuracy: 0.1250
# Epoch 2/5
# ...
# 10/10 [==============================] - 58s 6s/step - loss: 2.1494 - accuracy: 0.6443 - val_loss: 8402.2998 - val_accuracy: 0.1875
# Epoch 3/5
# ...
# 10/10 [==============================] - 56s 6s/step - loss: 0.9399 - accuracy: 0.7312 - val_loss: 100175.6250 - val_accuracy: 0.2500
# Epoch 4/5
# ...
# 10/10 [==============================] - 59s 6s/step - loss: 1.1070 - accuracy: 0.7437 - val_loss: 104244.2031 - val_accuracy: 0.1875
# Epoch 5/5
# ...
# 10/10 [==============================] - 56s 5s/step - loss: 0.5679 - accuracy: 0.8255 - val_loss: 55483.8906 - val_accuracy: 0.2500

# %%
acc=[96,51,19]
model=["CNN","VGG16","Densenet",]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=[10,5],dpi = 100)
plt.title('Accuracy Comparison for Train and Test Dataset')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = acc,y = model,palette='dark')
# Out:
# c:\Users\suman\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# <Axes: title={'center': 'Accuracy Comparison for Train and Test Dataset'}, xlabel='Accuracy', ylabel='Algorithm'>
